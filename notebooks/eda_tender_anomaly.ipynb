# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

print('Бібліотеки завантажено')
# Out:
# Бібліотеки завантажено

# %% [markdown]
# ## 1. Завантаження даних

# %%
df = pd.read_csv('../data/prepared/tender_anomaly_results.csv')
print(f'Розмір датасету: {df.shape}')
df.head()
# Out:
# Розмір датасету: (11000, 48)
#                 tender_id         cpv                status  \
# 0  UA-2025-12-04-018953-a  44110000-4        active.awarded
# 1  UA-2025-12-02-004413-a  71310000-4        active.awarded
# 2  UA-2025-12-09-017059-a  71900000-7              complete
# 3  UA-2025-11-10-007239-a  30230000-0  active.qualification
# 4  UA-2025-11-24-017432-a  38430000-8        active.awarded
#
#                                                title  \
# 0  Асфальтобетонна суміш «АСГ.Др.Щ.А.НП.І.БНД 70/...
# 1  Послуга з поточного ремонту з елементами модер...
# 2  Послуги з біохімічного пренатального скринінгу...
# 3  код ДК 021:2015-30230000-0 Комп’ютерне обладна...
# 4                                Аналізатори, 2 лота
#
#                                          description  log_value_amount  \
# 0  Умови доставки: EXW (Інкотермс 2020) – Постача...         15.656060
# 1                                Згідно специфікації         12.254868
# 2                                           НЕВІДОМО         10.993748
# 3  Закупівля здійснюється в рамках проекту техніч...         11.665432
# 4  Строк поставки товарів: 30 днів з дати отриман...         14.707629
#
#    log_winner_price  log_price_per_unit  log_value_per_day  numberOfBids  ...  \
# 0         15.648892           15.656060          14.046623             1  ...
# 1         12.206078           12.254868          10.308986             1  ...
# 2         10.993748            0.395896           0.000000             0  ...
# 3          0.000000           11.665432           8.298376             3  ...
# 4         14.187075           14.707629          12.761721             2  ...
#
#    semantic_cluster  semantic_score  semantic_outlier  semantic_pct  \
# 0                18        3.638318                 1      0.981364
# 1                33        5.139182                 1      0.993727
# 2                18        6.960628                 1      0.998727
# 3                -1        6.503950                 1      0.997818
# 4                26        3.301250                 1      0.976364
#
#    numeric_screen  numeric_score_adj_raw  numeric_score  numeric_pct  \
# 0               1              12.585129       8.288291     1.000000
# 1               1               4.746263       3.196762     0.981203
# 2               1               3.525586       2.352111     0.973684
# 3               0               2.701139       1.702840     0.969529
# 4               1               5.850955       4.463572     1.000000
#
#    risk_score  risk_rank
# 0    0.993788        1.0
# 1    0.993732        2.0
# 2    0.993728        3.0
# 3    0.992501        4.0
# 4    0.992121        5.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ## 2. Загальна інформація про дані

# %%
print('Типи даних та кількість ненульових значень')
df.info()
# Out:
# Типи даних та кількість ненульових значень
# <class 'pandas.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tender_id                     11000 non-null  str
#  1   cpv                           11000 non-null  str
#  2   status                        11000 non-null  str
#  3   title                         11000 non-null  str
#  4   description                   11000 non-null  str
#  5   log_value_amount              11000 non-null  float64
#  6   log_winner_price              11000 non-null  float64
#  7   log_price_per_unit            11000 non-null  float64
#  8   log_value_per_day             11000 non-null  float64
#  9   numberOfBids                  11000 non-null  int64
#  10  numberOfAdmitted              11000 non-null  int64
#  11  log_min_bid                   11000 non-null  float64
#  12  winner_minus_min              11000 non-null  float64
#  13  tender_duration_days          11000 non-null  float64
#  14  completion_days               11000 non-null  float64
#  15  complaints                    11000 non-null  int64
#  16  tender_changes                11000 non-null  int64
#  17  contract_changes              11000 non-null  int64
#  18  median_cpv                    11000 non-null  float64
#  19  cpv_deviation                 11000 non-null  float64
#  20  description_missing           11000 non-null  bool
#  21  value_amount_missing          11000 non-null  bool
#  22  winner_price_missing          11000 non-null  bool
#  23  price_per_unit_missing        11000 non-null  bool
#  24  value_per_day_missing         11000 non-null  bool
#  25  min_bid_missing               11000 non-null  bool
#  26  winner_minus_min_missing      11000 non-null  bool
#  27  tender_duration_days_missing  11000 non-null  bool
#  28  completion_days_missing       11000 non-null  bool
#  29  cpv_deviation_missing         11000 non-null  bool
#  30  text                          11000 non-null  str
#  31  total_missing_count           11000 non-null  int64
#  32  bids_cpv_zscore               11000 non-null  float64
#  33  admitted_cpv_zscore           11000 non-null  float64
#  34  admitted_ratio                11000 non-null  float64
#  35  winner_price                  11000 non-null  float64
#  36  price_drop_ratio              11000 non-null  float64
#  37  cpv2                          11000 non-null  int64
#  38  semantic_cluster              11000 non-null  int64
#  39  semantic_score                11000 non-null  float64
#  40  semantic_outlier              11000 non-null  int64
#  41  semantic_pct                  11000 non-null  float64
#  42  numeric_screen                11000 non-null  int64
#  43  numeric_score_adj_raw         11000 non-null  float64
#  44  numeric_score                 11000 non-null  float64
#  45  numeric_pct                   11000 non-null  float64
#  46  risk_score                    11000 non-null  float64
#  47  risk_rank                     11000 non-null  float64
# dtypes: bool(10), float64(22), int64(10), str(6)
# memory usage: 3.3 MB

# %%
print('Пропущені значення')
missing = df.isnull().sum()
print(missing[missing > 0] if missing.sum() > 0 else 'Пропущених значень немає!')
# Out:
# Пропущені значення
# Пропущених значень немає!

# %%
print('Описова статистика')
df.describe()
# Out:
# Описова статистика
#        log_value_amount  log_winner_price  log_price_per_unit  \
# count      11000.000000      11000.000000        11000.000000
# mean          10.317068          6.881976           10.041801
# std            3.078361          4.819544            3.449377
# min            0.000000          0.000000            0.000000
# 25%            8.100344          0.000000            7.795132
# 50%           10.348205          7.930404           10.302109
# 75%           12.521117         10.491302           12.516795
# max           21.321567         20.772056           21.321567
#
#        log_value_per_day  numberOfBids  numberOfAdmitted   log_min_bid  \
# count       11000.000000  11000.000000      11000.000000  11000.000000
# mean            5.337055      0.688909          0.688091      1.179943
# std             5.587103      1.630508          1.624849      3.473647
# min             0.000000      0.000000          0.000000      0.000000
# 25%             0.000000      0.000000          0.000000      0.000000
# 50%             0.000000      0.000000          0.000000      0.000000
# 75%            10.727712      1.000000          1.000000      0.000000
# max            20.606485     27.000000         27.000000     17.223520
#
#        winner_minus_min  tender_duration_days  completion_days  ...  \
# count      11000.000000          11000.000000     11000.000000  ...
# mean         501.821665              3.064818         3.064818  ...
# std        11688.756793              4.388311         4.388311  ...
# min            0.000000              0.000000         0.000000  ...
# 25%            0.000000              0.000000         0.000000  ...
# 50%            0.000000              0.000000         0.000000  ...
# 75%            0.000000              7.000000         7.000000  ...
# max       736617.600000            133.000000       133.000000  ...
#
#        semantic_cluster  semantic_score  semantic_outlier  semantic_pct  \
# count      11000.000000    1.100000e+04      11000.000000  11000.000000
# mean          16.901364    6.201100e-17          0.209182      0.500045
# std           13.244317    1.000045e+00          0.406743      0.205238
# min           -1.000000   -3.645079e-01          0.000000      0.395455
# 25%            2.000000   -3.645079e-01          0.000000      0.395455
# 50%           18.000000   -3.645079e-01          0.000000      0.395455
# 75%           28.000000   -3.645079e-01          0.000000      0.395455
# max           42.000000    1.062585e+01          1.000000      1.000000
#
#        numeric_screen  numeric_score_adj_raw  numeric_score   numeric_pct  \
# count    11000.000000           11000.000000   1.100000e+04  11000.000000
# mean         0.036091               0.135718   4.134067e-17      0.502091
# std          0.186525               1.474607   1.000000e+00      0.288734
# min          0.000000              -1.910959  -1.650606e+00      0.000755
# 25%          0.000000              -0.798215  -6.399551e-01      0.251906
# 50%          0.000000              -0.279936  -2.785307e-01      0.501657
# 75%          0.000000               0.610740   3.251718e-01      0.751887
# max          1.000000              23.754168   1.492272e+01      1.000000
#
#          risk_score     risk_rank
# count  11000.000000  11000.000000
# mean       0.371227   5500.316182
# std        0.264487   3175.573836
# min        0.131986      1.000000
# 25%        0.198082   2750.750000
# 50%        0.266186   5500.500000
# 75%        0.342190   8250.250000
# max        0.993788  11000.000000
#
# [8 rows x 32 columns]

# %% [markdown]
# ## 3. Аналіз цільової змінної (Target Distribution)

# %%
class_counts = df['risk_rank'].value_counts()
fraud_pct = df['risk_rank'].mean() * 100

print(f'Нормальних транзакцій:  {class_counts[0]:,} ({100 - fraud_pct:.3f}%)')
print(f'Шахрайських транзакцій: {class_counts[1]:,} ({fraud_pct:.3f}%)')

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Bar plot
axes[0].bar(['Normal (0)', 'Fraud (1)'], class_counts.values,
            color=['steelblue', 'crimson'], edgecolor='black')
axes[0].set_title('Кількість транзакцій за класами', fontsize=14)
axes[0].set_ylabel('Кількість')
for i, v in enumerate(class_counts.values):
    axes[0].text(i, v + 100, f'{v:,}', ha='center', fontweight='bold')

# Pie chart
axes[1].pie(class_counts.values, labels=['Normal', 'Fraud'],
            autopct='%1.3f%%', colors=['steelblue', 'crimson'],
            startangle=90, explode=(0, 0.1))
axes[1].set_title('Розподіл класів (%)', fontsize=14)

plt.tight_layout()
plt.savefig('../data/raw/target_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\procurement-anomaly-detection\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:1761, in pandas._libs.hashtable.Float64HashTable.get_item()
# -> 1761 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:1785, in pandas._libs.hashtable.Float64HashTable.get_item()
# -> 1785 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0.0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 class_counts = df['risk_rank'].value_counts()
#       2 fraud_pct = df['risk_rank'].mean() * 100
#       3
# ----> 4 print(f'Нормальних транзакцій:  {class_counts[0]:,} ({100 - fraud_pct:.3f}%)')
#       5 print(f'Шахрайських транзакцій: {class_counts[1]:,} ({fraud_pct:.3f}%)')
#       6
#       7 fig, axes = plt.subplots(1, 2, figsize=(12, 5))
#
# File ~\PycharmProjects\procurement-anomaly-detection\.venv\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~\PycharmProjects\procurement-anomaly-detection\.venv\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~\PycharmProjects\procurement-anomaly-detection\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %% [markdown]
# ## 4. Матриця кореляції

# %%
# Кореляція ознак з цільовою змінною
corr_with_target = df.corr()['Class'].drop('Class').sort_values(key=abs, ascending=False)

fig, ax = plt.subplots(figsize=(10, 8))
colors = ['crimson' if c > 0 else 'steelblue' for c in corr_with_target]
corr_with_target.plot(kind='barh', ax=ax, color=colors)
ax.set_title('Кореляція ознак з цільовою змінною (Class)', fontsize=14)
ax.set_xlabel('Pearson Correlation')
ax.axvline(x=0, color='black', linewidth=0.8)
plt.tight_layout()
plt.savefig('../data/raw/feature_correlation.png', dpi=150, bbox_inches='tight')
plt.show()

print('Топ-5 позитивно корельованих ознак:')
print(corr_with_target.head())
print('\nТоп-5 негативно корельованих ознак:')
print(corr_with_target.tail())

# %%
# Повна матриця кореляції (топ ознаки)
top_features = corr_with_target.abs().head(10).index.tolist() + ['Class']

fig, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(df[top_features].corr(), annot=True, fmt='.2f', cmap='RdBu_r',
            center=0, ax=ax, square=True)
ax.set_title('Матриця кореляції (топ-10 ознак + Class)', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Висновки EDA
#
# 1. **Дисбаланс класів**: Шахрайські транзакції складають лише ~0.17% від усіх даних. Для моделювання необхідно використовувати відповідні метрики (F1, Precision, Recall, AUC-ROC), а не лише accuracy.
#
# 2. **Пропущені значення**: Датасет не містить пропущених значень.
#
# 3. **Ознаки V1-V28**: Анонімізовані за допомогою PCA. Найбільш корельовані з цільовою змінною: V17, V14, V12, V10 (негативна кореляція), V4, V11 (позитивна).
#
# 4. **Amount та Time**: Не анонімізовані. Шахрайські транзакції мають нижчу середню суму, але є викиди з великими сумами.
#
# 5. **Стратегія моделювання**: Використовувати RandomForest з підібраним порогом класифікації та метриками F1/AUC-ROC. Розглянути клас-ваги або oversampling (SMOTE).
