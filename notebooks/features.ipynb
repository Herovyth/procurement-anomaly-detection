# %%
import pandas as pd

# Завантаження таблиць
df1 = pd.read_csv("../data/raw/relationship_level_features.csv")
df2 = pd.read_csv("../data/raw/supplier_level_features.csv")
df3 = pd.read_csv("../data/raw/tender_level_features.csv")

# Виведення ознак кожної таблиці
for i, df in enumerate([df1, df2, df3], start=1):
    features = pd.DataFrame({"Ознака": df.columns})
    print(f"Таблиця {i} — {df.shape[1]} ознак")
    display(features)
# Out:
# Таблиця 1 — 10 ознак
#                   Ознака
# 0               buyer_id
# 1            supplier_id
# 2            num_tenders
# 3              avg_price
# 4        avg_competitors
# 5       single_bid_share
# 6         buyer_locality
# 7      supplier_locality
# 8        buyer_win_share
# 9  supplier_income_share
# Таблиця 2 — 16 ознак
#                     Ознака
# 0              supplier_id
# 1                 num_bids
# 2                 num_wins
# 3          avg_competitors
# 4            rejected_bids
# 5               complaints
# 6       avg_price_per_unit
# 7             avg_contract
# 8             max_contract
# 9             min_contract
# 10  contract_changes_share
# 11                win_rate
# 12        log_avg_contract
# 13        log_max_contract
# 14        log_min_contract
# 15  log_avg_price_per_unit
# Таблиця 3 — 52 ознак
#                           Ознака
# 0                      tender_id
# 1                            cpv
# 2                         status
# ...
