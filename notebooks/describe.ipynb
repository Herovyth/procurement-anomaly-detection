# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('husl')

print('Бібліотеки завантажено')

# %%
df = pd.read_csv('../data/prepared/supplier_anomaly_results.csv')
print(f'Розмір датасету: {df.shape}')
df.head()
# Out:
# Розмір датасету: (18428, 21)
#   supplier_id  num_bids  num_wins  avg_competitors  rejected_bids  complaints  \
# 0   Приховано        45        45        17.777778              0           0
# 1    45582454         3         3         0.333333              0           0
# 2    31862978         7         6         0.428571              0           0
# 3    44763104        78        32         2.141026              0           1
# 4    42223804        37        13         4.081081              0           0
#
#    avg_price_per_unit  avg_contract  max_contract  min_contract  ...  \
# 0        5.747587e+08  1.019427e+08   143300000.0    1780270.96  ...
# 1        2.031483e+08  2.011862e+08   417060000.0   20399940.00  ...
# 2        1.560781e+08  1.819806e+08   548883300.0      91440.00  ...
# 3        4.842567e+06  1.042531e+07   306000000.0       5889.05  ...
# 4        1.643402e+07  2.908302e+07   210728921.9      23283.81  ...
#
#    win_rate  log_avg_contract  log_max_contract  log_min_contract  \
# 0  1.000000         18.439921         18.780451         14.392277
# 1  1.000000         19.119741         19.848741         16.831043
# 2  0.857143         19.019411         20.123396         11.423449
# 3  0.410256         16.159747         19.539096          8.681020
# 4  0.351351         17.185665         19.166083         10.055556
#
#    log_avg_price_per_unit  cluster  cluster_outlier  iforest_score  \
# 0               20.169461       -1             True       6.009536
# 1               19.129447       -1             True       5.411220
# 2               18.865867       -1             True       5.365144
# 3               15.392956       -1             True       5.362817
# 4               16.614864       -1             True       5.117688
#
#    risk_score  risk_rank
# 0   11.014305        1.0
# 1   10.116830        2.0
# 2   10.047716        3.0
# 3   10.044226        4.0
# 4    9.676532        5.0
#
# [5 rows x 21 columns]

# %%
print('Типи даних та кількість ненульових значень')
df.info()
# Out:
# Типи даних та кількість ненульових значень
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18428 entries, 0 to 18427
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   supplier_id             18428 non-null  object
#  1   num_bids                18428 non-null  int64
#  2   num_wins                18428 non-null  int64
#  3   avg_competitors         18428 non-null  float64
#  4   rejected_bids           18428 non-null  int64
#  5   complaints              18428 non-null  int64
#  6   avg_price_per_unit      18416 non-null  float64
#  7   avg_contract            9208 non-null   float64
#  8   max_contract            9208 non-null   float64
#  9   min_contract            9208 non-null   float64
#  10  contract_changes_share  18428 non-null  float64
#  11  win_rate                18428 non-null  float64
#  12  log_avg_contract        18428 non-null  float64
#  13  log_max_contract        18428 non-null  float64
#  14  log_min_contract        18428 non-null  float64
#  15  log_avg_price_per_unit  18428 non-null  float64
#  16  cluster                 18428 non-null  int64
#  17  cluster_outlier         18428 non-null  bool
#  18  iforest_score           18428 non-null  float64
#  19  risk_score              18428 non-null  float64
#  20  risk_rank               18428 non-null  float64
# dtypes: bool(1), float64(14), int64(5), object(1)
# memory usage: 2.8+ MB

# %%
print('Пропущені значення')
missing = df.isnull().sum()
print(missing[missing > 0] if missing.sum() > 0 else 'Пропущених значень немає!')
# Out:
# Пропущені значення
# avg_price_per_unit      12
# avg_contract          9220
# max_contract          9220
# min_contract          9220
# dtype: int64

# %%
print('Описова статистика')
df.describe()
# Out:
# Описова статистика
#            num_bids      num_wins  avg_competitors  rejected_bids  \
# count  18428.000000  18428.000000     18428.000000        18428.0
# mean       2.241046      0.785652         2.564093            0.0
# std        4.281649      1.712076         3.273768            0.0
# min        1.000000      0.000000         0.000000            0.0
# 25%        1.000000      0.000000         0.000000            0.0
# 50%        1.000000      0.000000         1.800000            0.0
# 75%        2.000000      1.000000         3.500000            0.0
# max       80.000000     80.000000        69.625000            0.0
#
#          complaints  avg_price_per_unit  avg_contract  max_contract  \
# count  18428.000000        1.841600e+04  9.208000e+03  9.208000e+03
# mean       0.027730        5.222738e+06  3.437498e+06  4.171204e+06
# std        0.349808        5.075103e+07  3.774542e+07  4.639960e+07
# min        0.000000        0.000000e+00  2.486300e+02  2.486300e+02
# 25%        0.000000        9.076944e+04  5.486300e+04  6.167460e+04
# 50%        0.000000        2.956200e+05  2.039955e+05  2.299995e+05
# 75%        0.000000        1.177735e+06  7.490000e+05  8.552500e+05
# max       16.000000        2.874307e+09  2.081974e+09  2.620174e+09
#
#        min_contract  contract_changes_share      win_rate  log_avg_contract  \
# count  9.208000e+03                 18428.0  18428.000000      18428.000000
# mean   3.005717e+06                     0.0      0.408611          6.128809
# std    3.194415e+07                     0.0      0.456046          6.304773
# min    7.597000e+01                     0.0      0.000000          0.000000
# 25%    3.546607e+04                     0.0      0.000000          0.000000
# 50%    1.605045e+05                     0.0      0.000000          0.000000
# 75%    5.888887e+05                     0.0      1.000000         12.223007
# max    1.543773e+09                     0.0      1.000000         21.456582
#
#        log_max_contract  log_min_contract  log_avg_price_per_unit  \
# count      18428.000000      18428.000000            18428.000000
# mean           6.192302          5.974027               12.734073
# std            6.371578          6.174678                2.095951
# min            0.000000          0.000000                0.000000
# 25%            0.000000          0.000000               11.411623
# 50%            0.000000          0.000000               12.595576
# 75%           12.345654         11.984330               13.978125
# max           21.686506         21.157495               21.779077
#
#             cluster  iforest_score    risk_score     risk_rank
# count  18428.000000   1.842800e+04  18428.000000  18428.000000
# mean     148.261233  -3.454777e-16      0.217170   9214.500000
# std      110.877854   1.000027e+00      1.692784   5319.849612
# min       -1.000000  -9.549177e-01     -1.432377      1.000000
# 25%       44.000000  -6.700919e-01     -0.964509   4605.500000
# 50%      145.000000  -3.183620e-01     -0.383833   9214.500000
# 75%      246.000000   3.109085e-01      0.880499  13821.250000
# max      350.000000   6.288775e+00     11.014305  18424.500000

# %%
df = pd.read_csv('../data/prepared/tender_anomaly_results.csv')
print(f'Розмір датасету: {df.shape}')
df.head()
# Out:
# Розмір датасету: (79000, 69)
#                 tender_id         cpv                status  \
# 0  UA-2025-10-27-004679-a  65120000-0        active.awarded
# 1  UA-2025-11-11-017293-a  42510000-4  active.qualification
# 2  UA-2025-12-02-013955-a  30190000-7        active.awarded
# 3  UA-2025-11-20-015715-a  66510000-8        active.awarded
# 4  UA-2025-11-19-009516-a  15840000-8        active.awarded
#
#                                                title  \
# 0  Послуги з хімічної регенерації мембранних елем...
# 1  Кондиціонери для потреб місцевих загальних суд...
# 2                                    Папір для друку
# 3  Послуги з обов'язкового страхування цивільно-п...
# 4  НОВОРІЧНІ ПОДАРУНКОВІ НАБОРИ СОЛОДОЩІВ (для ді...
#
#                                          description  value_amount  \
# 0                                           НЕВІДОМО    4738541.67
# 1  (Закупівля проводиться на ОЧІКУВАНУ ВАРТІСТЬ!!...    2592000.00
# 2  Категорія замовника: юридична особа, яка забез...    3750000.00
# 3  Мова (мови), якою (якими) повинні готуватися т...     464660.00
# 4  НОВОРІЧНІ ПОДАРУНКОВІ НАБОРИ СОЛОДОЩІВ (для ді...     404800.00
#
#    winner_price  price_per_unit  value_per_day  numberOfBids  ...  \
# 0    4455000.00      4738541.67   5.923177e+05             3  ...
# 1      51131.55      2592000.00   9.257143e+04             4  ...
# 2    3195000.00      3750000.00   1.875000e+06             7  ...
# 3     385912.00       464660.00   4.224182e+04             2  ...
# 4     313720.00       404800.00   3.680000e+04             5  ...
#
#    semantic_cluster  semantic_outlier  semantic_score  numeric_score  \
# 0                -1              True        1.501308       6.628801
# 1                -1              True        3.258574       3.943804
# 2                -1              True        2.273719       4.896893
# 3               642             False        4.599719       3.407481
# 4                -1              True        2.836755       3.883759
#
#    numeric_pct  semantic_pct  risk_blend  risk_score  risk_rank  \
# 0     1.000000      0.918658    0.972886   10.880763        1.0
# 1     0.997347      0.997405    0.998546   10.831665        2.0
# 2     1.000000      0.978253    0.992751   10.307472        3.0
# 3     0.998239      0.999956    0.555150   10.307059        4.0
# 4     0.999190      0.993025    0.997495   10.138892        5.0
#
#    global_risk_rank
# 0             153.0
# 1               1.0
# 2              15.0
# 3           19616.0
# 4               2.0
#
# [5 rows x 69 columns]

# %%
print('Типи даних та кількість ненульових значень')
df.info()
# Out:
# Типи даних та кількість ненульових значень
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79000 entries, 0 to 78999
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tender_id                     79000 non-null  object
#  1   cpv                           79000 non-null  object
#  2   status                        79000 non-null  object
#  3   title                         79000 non-null  object
#  4   description                   79000 non-null  object
#  5   value_amount                  79000 non-null  float64
#  6   winner_price                  79000 non-null  float64
#  7   price_per_unit                79000 non-null  float64
#  8   value_per_day                 79000 non-null  float64
#  9   numberOfBids                  79000 non-null  int64
#  10  numberOfAdmitted              79000 non-null  int64
#  11  min_bid                       79000 non-null  float64
#  12  winner_minus_min              79000 non-null  float64
#  13  tender_duration_days          79000 non-null  float64
#  14  completion_days               79000 non-null  float64
#  15  complaints                    79000 non-null  int64
#  16  tender_changes                79000 non-null  int64
#  17  contract_changes              79000 non-null  int64
#  18  documents_count               79000 non-null  float64
#  19  documents_distinct_types      79000 non-null  float64
#  20  documents_with_url            79000 non-null  float64
#  21  documents_format_pdf          79000 non-null  float64
#  22  documents_downloaded_count    79000 non-null  float64
#  23  documents_download_bytes      79000 non-null  float64
#  24  doc_text_features_missing     79000 non-null  float64
#  25  median_cpv                    78885 non-null  float64
#  26  cpv_deviation                 79000 non-null  float64
#  27  description_missing           79000 non-null  bool
#  28  doc_nlp_pca_1                 79000 non-null  float64
#  29  doc_nlp_pca_2                 79000 non-null  float64
#  30  doc_nlp_pca_3                 79000 non-null  float64
#  31  doc_nlp_pca_4                 79000 non-null  float64
#  32  doc_nlp_pca_5                 79000 non-null  float64
#  33  value_amount_missing          79000 non-null  bool
#  34  winner_price_missing          79000 non-null  bool
#  35  price_per_unit_missing        79000 non-null  bool
#  36  value_per_day_missing         79000 non-null  bool
#  37  min_bid_missing               79000 non-null  bool
#  38  winner_minus_min_missing      79000 non-null  bool
#  39  tender_duration_days_missing  79000 non-null  bool
#  40  completion_days_missing       79000 non-null  bool
#  41  cpv_deviation_missing         79000 non-null  bool
#  42  doc_nlp_pca_1_missing         79000 non-null  bool
#  43  doc_nlp_pca_2_missing         79000 non-null  bool
#  44  doc_nlp_pca_3_missing         79000 non-null  bool
#  45  doc_nlp_pca_4_missing         79000 non-null  bool
#  46  doc_nlp_pca_5_missing         79000 non-null  bool
#  47  log_value_amount              79000 non-null  float64
#  48  log_winner_price              79000 non-null  float64
#  49  log_price_per_unit            79000 non-null  float64
#  50  log_value_per_day             79000 non-null  float64
#  51  log_min_bid                   79000 non-null  float64
#  52  text                          79000 non-null  object
#  53  total_missing_count           79000 non-null  int64
#  54  bids_cpv_zscore               79000 non-null  float64
#  55  admitted_cpv_zscore           79000 non-null  float64
#  56  admitted_ratio                79000 non-null  float64
#  57  price_drop_ratio              79000 non-null  float64
#  58  cpv2                          79000 non-null  int64
#  59  semantic_cluster              79000 non-null  int64
#  60  semantic_outlier              79000 non-null  bool
#  61  semantic_score                79000 non-null  float64
#  62  numeric_score                 79000 non-null  float64
#  63  numeric_pct                   79000 non-null  float64
#  64  semantic_pct                  79000 non-null  float64
#  65  risk_blend                    79000 non-null  float64
#  66  risk_score                    79000 non-null  float64
#  67  risk_rank                     79000 non-null  float64
#  68  global_risk_rank              79000 non-null  float64
# dtypes: bool(16), float64(39), int64(8), object(6)
# memory usage: 33.1+ MB

# %%
print('Пропущені значення')
missing = df.isnull().sum()
print(missing[missing > 0] if missing.sum() > 0 else 'Пропущених значень немає!')
# Out:
# Пропущені значення
# median_cpv    115
# dtype: int64

# %%
print('Описова статистика')
df.describe()
# Out:
# Описова статистика
#        value_amount  winner_price  price_per_unit  value_per_day  \
# count  7.900000e+04  7.900000e+04    7.900000e+04   7.900000e+04
# mean   1.670728e+06  6.201376e+05    1.667286e+06   2.821954e+05
# std    3.096670e+07  1.718189e+07    3.096641e+07   5.505520e+06
# min    0.000000e+00  1.000000e-02    0.000000e+00   2.142857e+00
# 25%    2.600000e+03  2.600000e+03    1.898000e+03   3.137505e+04
# 50%    1.730000e+04  8.821000e+03    1.500000e+04   4.150000e+04
# 75%    1.410000e+05  4.001801e+04    1.377108e+05   5.000000e+04
# max    2.874307e+09  2.620174e+09    2.874307e+09   8.897800e+08
#
#        numberOfBids  numberOfAdmitted       min_bid  winner_minus_min  \
# count  79000.000000      79000.000000  7.900000e+04      7.900000e+04
# mean       0.590747          0.590063  1.123876e+05      8.066663e+02
# std        1.589483          1.587450  7.962109e+05      2.982621e+04
# min        0.000000          0.000000  5.700000e+01      0.000000e+00
# 25%        0.000000          0.000000  4.785000e+04      0.000000e+00
# 50%        0.000000          0.000000  6.050200e+04      0.000000e+00
# 75%        1.000000          1.000000  7.348065e+04      0.000000e+00
# max       75.000000         75.000000  6.885000e+07      4.887228e+06
#
#        tender_duration_days  completion_days  ...          cpv2  \
# count          79000.000000     79000.000000  ...  79000.000000
# mean               6.080392         6.080392  ...     36.021835
# std                4.050005         4.050005  ...     20.131141
# min                1.000000         1.000000  ...      3.000000
# 25%                4.000000         4.000000  ...     19.000000
# 50%                7.000000         7.000000  ...     33.000000
# 75%                7.000000         7.000000  ...     44.000000
# max              387.000000       387.000000  ...     99.000000
#
#        semantic_cluster  semantic_score  numeric_score   numeric_pct  \
# count      79000.000000    7.900000e+04   7.900000e+04  79000.000000
# mean         357.884797    4.605036e-17  -4.605036e-17      0.500291
# std          305.050171    1.000006e+00   1.000006e+00      0.288678
# min           -1.000000   -2.831734e+00  -1.420528e+00      0.000126
# 25%           -1.000000   -7.226927e-01  -7.076390e-01      0.250296
# 50%          343.000000   -9.872206e-02  -4.117469e-01      0.500255
# 75%          647.000000    6.277847e-01   5.013159e-01      0.750284
# max          863.000000    5.647414e+00   6.628801e+00      1.000000
#
#        semantic_pct    risk_blend    risk_score     risk_rank  \
# count  79000.000000  79000.000000  79000.000000  79000.000000
# mean       0.500006      0.397124      0.536759  39500.499329
# std        0.288677      0.238039      2.168526  22805.480335
# min        0.000013      0.002511     -5.075354      1.000000
# 25%        0.250009      0.211655     -1.098902  19750.750000
# 50%        0.500006      0.339153      0.316923  39500.500000
# 75%        0.749994      0.551631      1.923254  59250.250000
# max        1.000000      0.998546     10.880763  79000.000000
#
#        global_risk_rank
# count      79000.000000
# mean       39500.499329
# std        22805.480305
# min            1.000000
# 25%        19750.750000
# 50%        39500.500000
# 75%        59250.250000
# max        79000.000000
#
# [8 rows x 47 columns]
